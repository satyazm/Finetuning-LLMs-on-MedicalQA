# %% [markdown]
# # 05 - Evaluation comparison (baseline vs LoRA vs QLoRA)
#
# Runs locally (no GPU needed): aggregates the results already produced by `02_baseline`, `03_lora`, and `04_qlora`, and adds BERTScore on top of the ROUGE/latency/memory/training-time numbers already saved.
#
# **Known gap**: `results/baseline.csv` (the per-example predictions) was lost when that Kaggle session ended before it was downloaded - only the aggregate summary survived. BERTScore needs the actual prediction text, so baseline's BERTScore is unavailable unless `02_baseline.ipynb` is re-run to regenerate it.

# %%
# %pip install -q pandas evaluate bert-score
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys

cwd = os.getcwd()
REPO_ROOT = os.path.dirname(cwd) if os.path.basename(cwd) == "notebooks" else cwd

sys.path.append(REPO_ROOT)
os.chdir(REPO_ROOT)

# %% [markdown]
# ## Build the comparison table
#
# `build_comparison_table` reads each run's summary JSON, and where a CSV with predictions exists, adds BERTScore on top.

# %%
from src.evaluation.evaluate import build_comparison_table

runs = {
    "baseline": {"summary": "results/baseline_summary.json", "csv": "results/baseline.csv"},
    "lora": {"summary": "results/lora_summary.json", "csv": "results/lora.csv"},
    "qlora": {"summary": "results/qlora_summary.json", "csv": "results/qlora.csv"},
}

comparison = build_comparison_table(runs)
comparison
# Out:
# /Users/satyamyadav/Projects/PEFT/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using the latest cached version of the module from /Users/satyamyadav/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore/cf4907b18f8f741f202232c0f8009a3bd49ff98802c245abcb6ea51a37a8c05b (last modified on Sun Aug  2 10:46:51 2026) since it couldn't be found locally at evaluate-metric--bertscore, or remotely on the Hugging Face Hub.
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c8eda2f1-d260-44f2-b640-65a38f098f3a)')' thrown while requesting HEAD https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /roberta-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 8] nodename nor servname provided, or not known)"))'), '(Request ID: aa075308-5eb9-4631-a28e-d3530287bbbf)')' thrown while requesting HEAD https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /roberta-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 8] nodename nor servname provided, or not known)"))'), '(Request ID: ce84acfb-04b5-4d4b-978d-bbe9653b4020)')' thrown while requesting HEAD https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /roberta-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 8] nodename nor servname provided, or not known)"))'), '(Request ID: 23627162-802f-4825-b0f2-e144b6332224)')' thrown while requesting HEAD https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json
# Retrying in 8s [Retry 4/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /roberta-large/resolve/main/tokenizer_config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 8] nodename nor servname provided, or not known)"))'), '(Request ID: 8f49a5dc-64a3-4e49-9504-2ee383c5d36e)')' thrown while requesting HEAD https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json
# Retrying in 8s [Retry 5/5].
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#             rouge1    rouge2    rougeL  rougeLsum  mean_latency_sec  \
# model
# baseline  0.278117  0.062955  0.147609   0.182860          8.670415
# lora      0.390316  0.224572  0.299050   0.300353          8.359534
# qlora     0.371036  0.188960  0.269320   0.269718          8.106325
#
#           gpu_memory_gb  train_runtime_sec  train_loss  bertscore_precision  \
# model
# baseline       3.113441                NaN         NaN                  NaN
# lora           3.130938         12514.6912    1.061803             0.890560
# qlora          4.337065         10977.7214    1.087001             0.881552
#
#           bertscore_recall  bertscore_f1  peak_training_gpu_memory_gb
# model
# baseline               NaN           NaN                          NaN
# lora              0.865895      0.877636                          NaN
# qlora             0.864170      0.872412                         7.47

# %% [markdown]
# ## Save

# %%
import os

os.makedirs("results/tables", exist_ok=True)
comparison.to_csv("results/tables/comparison.csv")
print("Saved results/tables/comparison.csv")
# Out:
# Saved results/tables/comparison.csv
